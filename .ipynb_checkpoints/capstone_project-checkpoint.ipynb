# %%
import sys, os
sys.path.append(os.environ['minotaur'])

import datetime

import yaml

# %matplotlib inline
from matplotlib import pyplot as plt

import pandas as pd
import numpy as np
import patsy
import statsmodels.api as sm

from pylab import rcParams
rcParams['figure.figsize'] = 14,3
rcParams['font.family'] = 'Open Sans'

from dbs import redshift
redshift.connect()

from __future__ import division
# Out:
# /usr/local/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
tasks = redshift.execute("""
SELECT t.activity_date,
       COALESCE(c.email,l.email) AS email,
       COALESCE(c.account_id,l.id) AS company_id,
       'sales' as source_table,
       t.type_c as activity_type,
       t.call_c as call_type
FROM segment_salesforce.tasks t
  LEFT JOIN segment_salesforce.contacts c
         ON t.who_id = c.id
        AND NOT c.is_deleted
  LEFT JOIN segment_salesforce.leads l
         ON t.who_id = l.id
        AND NOT l.is_deleted
WHERE NOT t.is_deleted AND (t.type_c = 'Email' OR t.type_c = 'Call')
""")
emails = redshift.execute("""
SELECT e.activity_date,
       p.email,
       p.company_id,
       'marketing' as source_table,
       'marketing_email' as activity_type,
       NULL as call_type
FROM marketo.email_delivers e
  INNER JOIN analytics.salesforce_patrons p ON e.lead_id = p.marketo_id
""")
opps = redshift.execute("""
SELECT id,
       account_id,
       stage_name,
       amount,
       created_date,
       close_date
       FROM segment_salesforce.opportunities
WHERE NOT is_deleted
AND   type = 'Activation'
AND (stage_name = 'Closed Won' OR stage_name = 'Closed Lost')
""")
site_landings = redshift.execute("""
SELECT sl.sent_at as activity_date,
       meam.email,
       sp.company_id,
       'site' as source_table,
       'site_visit' as activity_type,
       NULL as call_type
FROM analytics.site_landings sl
  INNER JOIN analytics.marketo_email_alias_mapping meam ON sl.looker_visitor_id = meam.looker_visitor_id
  INNER JOIN analytics.salesforce_patrons sp on meam.email = sp.email""")

# %%
t = tasks
e = emails
sl = site_landings
o = opps

# %%
con = pd.concat([t,e,sl],axis=0)

# %%
con.activity_type = con.activity_type.astype(str)
con.activity_type = con['activity_type'].apply(str.lower)
con.activity_type.unique()
# Out:
# array(['email', 'call', 'marketing_email', 'site_visit'], dtype=object)

# %%
con.call_type.unique()
# Out:
# array([None, 'No Answer', 'Connected', 'Left Voicemail', 'Not in Service',
#        'Rejected', 'Wrong Number', 'Busy'], dtype=object)

# %% [markdown]
# will work with only 1 input
#
# for activity_type, call_type in con:
#     if call_type == 'Connected':
#         con.activity_type = con.activity_type.replace('call', 'call_connect')
#     elif call_type == 'Rejected':
#         con.activity_type = con.activity_type.replace('call', 'call_reject')
#         continue
# con.activity_type.unique()

# %%
con.loc[con['call_type'] == 'Connected', 'activity_type'] = 'call_connect'
con.activity_type.unique()
# Out:
# array(['email', 'call', 'call_connect', 'marketing_email', 'site_visit'], dtype=object)

# %%
# trying to predict amount of time between activity and close. 
# trying to minimize time between activity and opportunity that is successful
# create dataset that combines site visits, emails, tasks with email address for each row
# add in opportunity
# sum up type by company_id and email

# %%
opps = pd.merge(con,o,left_on='company_id',right_on='account_id',how='left')

# %%
opps.email.size
# Out:
# 2515334

# %%
opps['activity_date'] = pd.to_datetime(opps['activity_date'])
opps['created_date'] = pd.to_datetime(opps['created_date'])
opps['close_date'] = pd.to_datetime(opps['close_date'])

# %%
opps['days'] = (opps.created_date - opps.activity_date).astype('timedelta64[D]')
opps['has_opp'] = ((opps.days <= 30) & (opps.days >= 0))
opps.head()
# Out:
#   activity_date                        email          company_id source_table  \
# 0    2017-03-31        berlinblueart@mail.de  001C000001ZdVpGIAV        sales
# 1    2017-03-31      info@rolandoanselmi.com  001C000001QmZtsIAF        sales
# 2    2017-03-31      info@rolandoanselmi.com  001C000001QmZtsIAF        sales
# 3    2017-03-31  danielle@daniellearnaud.com  001C000001T2HzFIAV        sales
# 4    2017-03-31  danielle@daniellearnaud.com  001C000001T2HzFIAV        sales
#
#   activity_type call_type                  id          account_id  \
# 0         email      None  006C0000015ebgjIAA  001C000001ZdVpGIAV
# 1         email      None  006C0000012K9cKIAS  001C000001QmZtsIAF
# 2         email      None  006C0000015ecvgIAA  001C000001QmZtsIAF
# 3         email      None  006C0000011hwlFIAQ  001C000001T2HzFIAV
# 4         email      None  006C000001255qFIAQ  001C000001T2HzFIAV
#
#     stage_name  amount        created_date close_date   days  has_opp
# 0   Closed Won  6840.0 2017-03-08 10:40:41 2017-03-31  -23.0    False
# 1  Closed Lost    None 2016-02-25 19:36:18 2016-03-31 -400.0    False
# 2  Closed Lost    None 2017-03-08 14:27:16 2017-04-22  -23.0    False
# 3  Closed Lost    None 2016-01-22 10:21:54 2016-02-29 -434.0    False
# 4  Closed Lost    None 2016-02-12 10:33:46 2016-03-31 -413.0    False

# %%
hops = opps[opps.has_opp == True].copy()
hops.head()
# Out:
#    activity_date                          email          company_id  \
# 9     2017-03-31  galeria@lbcontemporaryart.com  001C000001Y4R5vIAF
# 27    2017-03-31              tracy@arkitip.com  001C000001WBBzZIAX
# 33    2017-03-31     azabawa@oneriverschool.com  001C000001aSZTjIAO
# 39    2017-04-01             roxana@galateca.ro  001C000001Une4SIAR
# 43    2017-04-01             roxana@galateca.ro  001C000001Une4SIAR
#
#    source_table activity_type  call_type                  id  \
# 9         sales         email       None  006C0000015gPCBIA2
# 27        sales         email       None  006C0000015gRHWIA2
# 33        sales         email       None  006C0000015gRdLIAU
# 39        sales          call  No Answer  006C0000015gUc7IAE
# 43        sales  call_connect  Connected  006C0000015gUc7IAE
#
#             account_id   stage_name amount        created_date close_date  \
# 9   001C000001Y4R5vIAF  Closed Lost   None 2017-03-31 14:25:36 2017-05-15
# 27  001C000001WBBzZIAX  Closed Lost   None 2017-03-31 19:32:17 2017-05-12
# 33  001C000001aSZTjIAO  Closed Lost   None 2017-03-31 20:54:03 2017-05-15
# 39  001C000001Une4SIAR  Closed Lost   None 2017-04-03 08:55:02 2017-05-18
# 43  001C000001Une4SIAR  Closed Lost   None 2017-04-03 08:55:02 2017-05-18
#
#     days  has_opp
# 9    0.0     True
# 27   0.0     True
# 33   0.0     True
# 39   2.0     True
# 43   2.0     True

# %%
hops['company_opp'] = hops.company_id.map(str) + hops.id.map(str)
hops.head()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    activity_date                          email          company_id  \
# 9     2017-03-31  galeria@lbcontemporaryart.com  001C000001Y4R5vIAF
# 27    2017-03-31              tracy@arkitip.com  001C000001WBBzZIAX
# 33    2017-03-31     azabawa@oneriverschool.com  001C000001aSZTjIAO
# 39    2017-04-01             roxana@galateca.ro  001C000001Une4SIAR
# 43    2017-04-01             roxana@galateca.ro  001C000001Une4SIAR
#
#    source_table activity_type  call_type                  id  \
# 9         sales         email       None  006C0000015gPCBIA2
# 27        sales         email       None  006C0000015gRHWIA2
# 33        sales         email       None  006C0000015gRdLIAU
# 39        sales          call  No Answer  006C0000015gUc7IAE
# 43        sales  call_connect  Connected  006C0000015gUc7IAE
#
#             account_id   stage_name amount        created_date close_date  \
# 9   001C000001Y4R5vIAF  Closed Lost   None 2017-03-31 14:25:36 2017-05-15
# 27  001C000001WBBzZIAX  Closed Lost   None 2017-03-31 19:32:17 2017-05-12
# 33  001C000001aSZTjIAO  Closed Lost   None 2017-03-31 20:54:03 2017-05-15
# 39  001C000001Une4SIAR  Closed Lost   None 2017-04-03 08:55:02 2017-05-18
# 43  001C000001Une4SIAR  Closed Lost   None 2017-04-03 08:55:02 2017-05-18
#
#     days  has_opp                           company_opp
# 9    0.0     True  001C000001Y4R5vIAF006C0000015gPCBIA2
# 27   0.0     True  001C000001WBBzZIAX006C0000015gRHWIA2
# 33   0.0     True  001C000001aSZTjIAO006C0000015gRdLIAU
# 39   2.0     True  001C000001Une4SIAR006C0000015gUc7IAE
# 43   2.0     True  001C000001Une4SIAR006C0000015gUc7IAE

# %%
company_opps = hops.company_opp.unique()

# %%
df = []
for company_opp in company_opps:
    d = dict(hops[hops.company_opp == company_opp].activity_type.value_counts())
    d['id'] = company_opp
    df += [d]
df = pd.DataFrame(df)

# %%
df = df.fillna(0)
df2 = df.set_index(['id'],drop=True)
df2.head()
# Out:
#                                       call  call_connect  email  \
# id
# 001C000001Y4R5vIAF006C0000015gPCBIA2   0.0           1.0    4.0
# 001C000001WBBzZIAX006C0000015gRHWIA2   0.0           1.0    4.0
# 001C000001aSZTjIAO006C0000015gRdLIAU   1.0           1.0    6.0
# 001C000001Une4SIAR006C0000015gUc7IAE   4.0           2.0    2.0
# 001C000001aTieQIAS006C0000015gxsRIAQ   4.0           0.0   10.0
#
#                                       marketing_email  site_visit
# id
# 001C000001Y4R5vIAF006C0000015gPCBIA2              0.0         0.0
# 001C000001WBBzZIAX006C0000015gRHWIA2              0.0         0.0
# 001C000001aSZTjIAO006C0000015gRdLIAU              1.0         0.0
# 001C000001Une4SIAR006C0000015gUc7IAE              0.0         0.0
# 001C000001aTieQIAS006C0000015gxsRIAQ              2.0         9.0

# %%
won = hops.set_index('company_opp',drop=True)
won['is_won'] = won.stage_name == 'Closed Won'
won.head()
# Out:
#                                      activity_date  \
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2    2017-03-31
# 001C000001WBBzZIAX006C0000015gRHWIA2    2017-03-31
# 001C000001aSZTjIAO006C0000015gRdLIAU    2017-03-31
# 001C000001Une4SIAR006C0000015gUc7IAE    2017-04-01
# 001C000001Une4SIAR006C0000015gUc7IAE    2017-04-01
#
#                                                               email  \
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2  galeria@lbcontemporaryart.com
# 001C000001WBBzZIAX006C0000015gRHWIA2              tracy@arkitip.com
# 001C000001aSZTjIAO006C0000015gRdLIAU     azabawa@oneriverschool.com
# 001C000001Une4SIAR006C0000015gUc7IAE             roxana@galateca.ro
# 001C000001Une4SIAR006C0000015gUc7IAE             roxana@galateca.ro
#
#                                               company_id source_table  \
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2  001C000001Y4R5vIAF        sales
# 001C000001WBBzZIAX006C0000015gRHWIA2  001C000001WBBzZIAX        sales
# 001C000001aSZTjIAO006C0000015gRdLIAU  001C000001aSZTjIAO        sales
# 001C000001Une4SIAR006C0000015gUc7IAE  001C000001Une4SIAR        sales
# 001C000001Une4SIAR006C0000015gUc7IAE  001C000001Une4SIAR        sales
#
#                                      activity_type  call_type  \
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2         email       None
# 001C000001WBBzZIAX006C0000015gRHWIA2         email       None
# 001C000001aSZTjIAO006C0000015gRdLIAU         email       None
# 001C000001Une4SIAR006C0000015gUc7IAE          call  No Answer
# 001C000001Une4SIAR006C0000015gUc7IAE  call_connect  Connected
#
#                                                       id          account_id  \
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2  006C0000015gPCBIA2  001C000001Y4R5vIAF
# 001C000001WBBzZIAX006C0000015gRHWIA2  006C0000015gRHWIA2  001C000001WBBzZIAX
# 001C000001aSZTjIAO006C0000015gRdLIAU  006C0000015gRdLIAU  001C000001aSZTjIAO
# 001C000001Une4SIAR006C0000015gUc7IAE  006C0000015gUc7IAE  001C000001Une4SIAR
# 001C000001Une4SIAR006C0000015gUc7IAE  006C0000015gUc7IAE  001C000001Une4SIAR
#
#                                        stage_name amount        created_date  \
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2  Closed Lost   None 2017-03-31 14:25:36
# 001C000001WBBzZIAX006C0000015gRHWIA2  Closed Lost   None 2017-03-31 19:32:17
# 001C000001aSZTjIAO006C0000015gRdLIAU  Closed Lost   None 2017-03-31 20:54:03
# 001C000001Une4SIAR006C0000015gUc7IAE  Closed Lost   None 2017-04-03 08:55:02
# 001C000001Une4SIAR006C0000015gUc7IAE  Closed Lost   None 2017-04-03 08:55:02
#
#                                      close_date  days  has_opp  is_won
# company_opp
# 001C000001Y4R5vIAF006C0000015gPCBIA2 2017-05-15   0.0     True   False
# 001C000001WBBzZIAX006C0000015gRHWIA2 2017-05-12   0.0     True   False
# 001C000001aSZTjIAO006C0000015gRdLIAU 2017-05-15   0.0     True   False
# 001C000001Une4SIAR006C0000015gUc7IAE 2017-05-18   2.0     True   False
# 001C000001Une4SIAR006C0000015gUc7IAE 2017-05-18   2.0     True   False

# %%
won = won[['is_won']].copy()
won = won[~won.index.duplicated(keep='last')]
won.index.size
# Out:
# 6667

# %%
final = df2.join(won)
final.shape
final.to_csv('final.csv')
# Out:
# (6667, 6)

# %%
final.head(10)
# Out:
#                                       call  call_connect  email  \
# id
# 001C000001Y4R5vIAF006C0000015gPCBIA2   0.0           1.0    4.0
# 001C000001WBBzZIAX006C0000015gRHWIA2   0.0           1.0    4.0
# 001C000001aSZTjIAO006C0000015gRdLIAU   1.0           1.0    6.0
# 001C000001Une4SIAR006C0000015gUc7IAE   4.0           2.0    2.0
# 001C000001aTieQIAS006C0000015gxsRIAQ   4.0           0.0   10.0
# 001C000001aTiknIAC006C0000015hNtaIAE   2.0           0.0    9.0
# 001C000001aTjjpIAC006C0000015gwjGIAQ   0.0           2.0    3.0
# 001C000001Nz0wAIAR006C0000015gZzDIAU   0.0           1.0    1.0
# 001C000001QmZnkIAF006C0000015gd3iIAA   0.0           3.0    1.0
# 001C000001WBXZtIAP006C0000015gfx4IAA   0.0           2.0    1.0
#
#                                       marketing_email  site_visit  is_won
# id
# 001C000001Y4R5vIAF006C0000015gPCBIA2              0.0         0.0   False
# 001C000001WBBzZIAX006C0000015gRHWIA2              0.0         0.0   False
# 001C000001aSZTjIAO006C0000015gRdLIAU              1.0         0.0   False
# 001C000001Une4SIAR006C0000015gUc7IAE              0.0         0.0   False
# 001C000001aTieQIAS006C0000015gxsRIAQ              2.0         9.0    True
# 001C000001aTiknIAC006C0000015hNtaIAE              1.0        16.0    True
# 001C000001aTjjpIAC006C0000015gwjGIAQ              0.0         0.0   False
# 001C000001Nz0wAIAR006C0000015gZzDIAU              6.0         0.0   False
# 001C000001QmZnkIAF006C0000015gd3iIAA              2.0         0.0   False
# 001C000001WBXZtIAP006C0000015gfx4IAA              0.0         6.0    True

# %%
final.corr()
# Out:
#                      call  call_connect     email  marketing_email  \
# call             1.000000      0.173449  0.166288         0.079285
# call_connect     0.173449      1.000000  0.060847         0.108858
# email            0.166288      0.060847  1.000000         0.002574
# marketing_email  0.079285      0.108858  0.002574         1.000000
# site_visit       0.039403      0.048779  0.120178         0.158325
# is_won          -0.006366     -0.010833  0.157160        -0.033227
#
#                  site_visit    is_won
# call               0.039403 -0.006366
# call_connect       0.048779 -0.010833
# email              0.120178  0.157160
# marketing_email    0.158325 -0.033227
# site_visit         1.000000  0.128645
# is_won             0.128645  1.000000

# %%
X = final.copy()
del X['is_won']

# %%
y = final['is_won'].copy()

# %%
from sklearn.linearmodels import SGDRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-64b5289d3480> in <module>()
# ----> 1 from sklearn.linearmodels import SGDRegressor
#
# ModuleNotFoundError: No module named 'sklearn.linearmodels'
